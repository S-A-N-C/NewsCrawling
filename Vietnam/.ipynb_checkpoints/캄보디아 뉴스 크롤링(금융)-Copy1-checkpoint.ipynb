# %%
import requests
from pandas import DataFrame
from bs4 import BeautifulSoup
import re
from datetime import datetime
import os

from urllib.request import Request, urlopen # url open
import urllib.parse

import requests

# %%
# 파파고 api 메소드 (글자수 때매 사용 안함)

def get_translate(text):
    client_id = "zU05PnavleWtiyNb8xrJ" # <-- client_id 기입
    client_secret = "GGWHMfmwyH" # <-- client_secret 기입

    data = {'text' : text,
            'source' : 'en',
            'target': 'ko'}

    url = "https://openapi.naver.com/v1/papago/n2mt"

    header = {"X-Naver-Client-Id":client_id,
              "X-Naver-Client-Secret":client_secret}

    response = requests.post(url, headers=header, data=data)
    rescode = response.status_code

    if(rescode==200):
        send_data = response.json()
        trans_data = (send_data['message']['result']['translatedText'])
        return trans_data
    else:
        print("Error Code:" , rescode)

# %%
# csv 파일 만들기 위해서

date = str(datetime.now()) 
date = date[:date.rfind(':')].replace(' ', '_') 
date = date.replace(':','시') + '분'

# %%
# 베트남 뉴스 크롤링 할 때, 월로 비교
# 같은 달이면 크롤링, 달이 다를 경우 크롤링 스톱
# 입력하는 형태로 할지 고민 중
month = datetime.now()
this_month = month.month
print(this_month)
month = month.strftime('%B')
print(month)
# Out:
# 8
# August

# %%
# 그냥 열면 403 에러 발생
# mod_security 또는 다른 비슷한 서버 시큐리티가 알려진 사용자 봇을 블록 시킴

# 시작 페이지
    
page = '1'

urlTicker = Request('https://www.khmertimeskh.com/category/property/page/' + page, headers={'User-Agent': 'Mozilla/5.0'})
webpage = urlopen(urlTicker).read()
soup = BeautifulSoup(webpage, 'html.parser')

# %%
#엑셀 만들 때 사용
news_dict = {} 
idx = 0

# %%
# 여기 안 돌려도 됨

news_date = soup.find(class_='item-meta')
news_date2 = news_date.find_all(class_='item-time')
#print(news_date)

print(news_date2)





#이걸로
test = soup.select('time')

#print(test)

print(len(test))


for i in test:
    print(i)
    #print(i.attrs[datetime])


#날짜 완료
month2 = test[5:7]

#test3 = soup.find_all(class_="item-time")['datetime']


#print(month2)

check = str(this_month).zfill(2)
#print(str(this_month).zfill(2))

#print(month2 == check)
# Out:
# [<time class="item-time" datetime="2022-08-10T01:12:28+07:00">August 10, 2022</time>]
# 30
# <time class="item-time" datetime="2022-08-10T01:12:28+07:00">August 10, 2022</time>
# <time class="item-time" datetime="2022-08-10T01:11:30+07:00">August 10, 2022</time>
# <time class="item-time" datetime="2022-08-08T01:04:19+07:00">August 8, 2022</time>
# <time class="item-time" datetime="2022-08-03T01:12:27+07:00">August 3, 2022</time>
# <time class="item-time" datetime="2022-08-03T01:11:24+07:00">August 3, 2022</time>
# <time class="item-time" datetime="2022-08-03T01:01:26+07:00">August 3, 2022</time>
# <time class="item-time" datetime="2022-08-02T01:07:03+07:00">August 2, 2022</time>
# <time class="item-time" datetime="2022-07-27T01:12:56+07:00">July 27, 2022</time>
# <time class="item-time" datetime="2022-07-27T01:11:53+07:00">July 27, 2022</time>
# <time class="item-time" datetime="2022-07-27T01:03:45+07:00">July 27, 2022</time>
# ...

# %%
# for문 돌면서 크롤링
first_check = 1

while True:
    
    
    # 전체 돌릴 때 이걸로 해야 함
    link = soup.find_all(class_='item-content')
    #title = link.find(class_='item-title')
    
    
    #if  달이 다르면 종료
    if page == '11':
        break



    for i in link:
        newsTitle = i.find(class_='item-title').get_text()
        newsDate = i.find(class_='item-time').get_text()
        newsURL = i.find("a")["href"]
        real_content = i.find("p").get_text()
        
        # for문 종료 및 출력 (테스트 출력)

        print(newsTitle)    # 제목
        print(newsDate)     # 날짜
        print(newsURL)      # url
        print(real_content) # 본문
        # Korean_content = get_translate(real_content) 파파고 진행 안함
        #print(Korean_content) # 한국어 번역
        print('\n')
        
        news_dict[idx] = {'title' : newsTitle,
                          'date' : newsDate,
                              'url' : newsURL,
                             'content' : real_content}
                             #'Korean' : Korean_content}

        idx += 1
        
    page = int(page)
    page += 1
    page = str(page)
    print(page)  # page 체크라 지워도 됨
        
    urlTicker = Request('https://www.khmertimeskh.com/category/property/page/' + page, headers={'User-Agent': 'Mozilla/5.0'})
    webpage = urlopen(urlTicker).read()
    soup = BeautifulSoup(webpage, 'html.parser')
# Out:
# Across New York, renters desperate as soaring rents exacerbate housing crisis
# August 10, 2022
# https://www.khmertimeskh.com/501129260/across-new-york-renters-desperate-as-soaring-rents-exacerbate-housing-crisis/
# In mid-May, Paula Sevilla and her roommates joined the many New Yorkers suffering under the city’s crushing housing crisis, which has seen rents soar in the pandemic’s wake.
#
#
# Intercity Roads Approach Completion in Coastal Province Sihanoukville
# August 10, 2022
# https://www.khmertimeskh.com/501129262/intercity-roads-approach-completion-in-coastal-province-sihanoukville/
# Preah Sihanouk intercity roads are approaching completion at 99.81% according to the Ministry of Public Works and Transport (MPWT).
#
#
# Working to Forge a Win-Win and “Innovative” Future Together Phnom Penh’s First 6A-Grade Intelligent Office Building Presentation
# August 8, 2022
# ...

# %%
print('크롤링 완료')

print('데이터프레임 변환')
news_df = DataFrame(news_dict).T

folder_path = os.getcwd()
xlsx_file_name = '캄보디아 뉴스_{}.xlsx'.format(date)

news_df.to_excel(xlsx_file_name)

print('엑셀 저장 완료 | 경로 : {}\\{}'.format(folder_path, xlsx_file_name))
os.startfile(folder_path)
# Out:
# 크롤링 완료
# 데이터프레임 변환
# 엑셀 저장 완료 | 경로 : C:\Users\Cyber\Crawling\NewsCrawling\새 폴더\NewsCrawling\Cambodia\캄보디아 뉴스_2022-08-16_18시11분.xlsx
